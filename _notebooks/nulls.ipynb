# %% [markdown]
# # Nulls
#
# Exploring empty cells in the dataset.

# %%
import pandas as pd

# %%
df = pd.read_csv("../.warn-transformer/processed/consolidated.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39346 entries, 0 to 39345
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   hash_id      39346 non-null  object
#  1   jobs         38856 non-null  float64
#  2   date         39340 non-null  object
#  3   company      39346 non-null  object
#  4   location     35188 non-null  object
#  5   postal_code  39346 non-null  object
# dtypes: float64(1), object(5)
# memory usage: 1.8+ MB

# %%
df.head()
# Out:
#                                              hash_id   jobs        date  \
# 0  b855422a87ece9da20ec6571e2f8f6f48521d4e06610e5...   40.0  2021-09-16
# 1  2214cbc57e63037a436152aeb018819a5e8777e2e8eab1...  134.0  2021-07-02
# 2  20c76d62449eb697b6f95288b8982e36586afd99fc7b7c...  185.0  2021-04-30
# 3  0ca0a89d9a684741de7f5199ef69ffc948b5df7e93e22c...   59.0  2021-04-12
# 4  b7c5bb7e614fcce37f1f8c7ba00786faa5482270039b5c...    NaN  2020-09-30
#
#                                              company  \
# 0                                        Bean’s Cafe
# 1                                 Kakivik Asset Mgmt
# 2                                      First Student
# 3                            GCI Communication Group
# 4  RavnAir Group, Corvus Airlines, Hageland Aviat...
#
#                                             location postal_code
# 0                                          Anchorage          AK
# 1                                        Prudhoe Bay          AK
# ...

# %% [markdown]
# ## Dates

# %%
df[df.date.isnull()].groupby("postal_code").size().rename("total").reset_index()
# Out:
#   postal_code  total
# 0          NJ      3
# 1          RI      3

# %% [markdown]
# ## Company

# %%
df[df.company.isnull()].groupby("postal_code").size().rename("total").reset_index()
# Out:
# Empty DataFrame
# Columns: [postal_code, total]
# Index: []

# %% [markdown]
# ## Location

# %%
df[df.location.isnull()].groupby("postal_code").size().rename("total").reset_index()
# Out:
#    postal_code  total
# 0           AL      4
# 1           AZ    172
# 2           CA    370
# 3           DC     70
# 4           DE     92
# 5           GA      1
# 6           KS   2026
# 7           MD      1
# 8           ME    297
# 9           MO      1
# 10          NE      8
# 11          NY     18
# 12          OK    743
# 13          OR     54
# 14          TX     10
# 15          VA      1
# 16          VT    288
# 17          WA      1
# 18          WI      1

# %% [markdown]
# ## Jobs

# %%
df[df.jobs.isnull()].groupby("postal_code").size().rename("total").reset_index()
# Out:
#    postal_code  total
# 0           AK      2
# 1           AL      1
# 2           CA      2
# 3           CT     28
# 4           DC      1
# 5           ID     17
# 6           IN     32
# 7           MD     44
# 8           MO     10
# 9           MT      2
# 10          NE    157
# 11          NJ     15
# 12          NM      3
# 13          NY    106
# 14          OR     34
# 15          RI      6
# 16          SD      1
# 17          TX     26
# 18          UT      1
# 19          WI      2
