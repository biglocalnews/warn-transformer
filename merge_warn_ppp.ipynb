# %%
# Input: standardize_dates.csv (WARN data) & PPP data from directory INPUT_DIR
# Output: merge_warn_ppp.csv to directory OUTPUT_DIR


import csv
import re
import requests
import os

import pandas as pd
from pathlib import Path

from utils import write_dict_rows_to_csv
from utils import write_rows_to_csv

USER_HOME = os.path.expanduser('~')
DEFAULT_HOME = str(Path(USER_HOME, '.warn-scraper'))
ETL_DIR = os.environ.get('WARN_ETL_DIR', DEFAULT_HOME)
WARN_DATA_PATH = str(Path(ETL_DIR, 'exports'))
WARN_CACHE_PATH = str(Path(ETL_DIR, 'cache'))
WARN_ANALYSIS_PATH = str(Path(ETL_DIR, 'analysis'))
INPUT_DIR = WARN_ANALYSIS_PATH
OUTPUT_DIR = WARN_ANALYSIS_PATH

# filenames to read from INPUT_DIR
# this is the compiled WARN file output by standardize_dates.py
WARN_FILENAME = "standardize_dates.csv"
# these are the names of the PPP files found on the sba.gov website
PPP_FILENAMES = ["public_150k_plus_211121.csv", "public_up_to_150k_1_211121.csv", "public_up_to_150k_2_211121.csv", "public_up_to_150k_3_211121.csv", "public_up_to_150k_4_211121.csv", "public_up_to_150k_5_211121.csv", "public_up_to_150k_6_211121.csv", "public_up_to_150k_7_211121.csv", "public_up_to_150k_8_211121.csv", "public_up_to_150k_9_211121.csv", "public_up_to_150k_10_211121.csv", "public_up_to_150k_11_211121.csv", "public_up_to_150k_12_211121.csv"]
OUTPUT_FILENAME = "merge_warn_ppp.csv"

Path(WARN_ANALYSIS_PATH).mkdir(parents=True, exist_ok=True)
warn_csv = f'{INPUT_DIR}/{WARN_FILENAME}'
ppp_csvs = [f'{INPUT_DIR}/{file}' for file in PPP_FILENAMES]
output_csv = f'{OUTPUT_DIR}/{OUTPUT_FILENAME}'

# names of columns
ppp_company_col = 'BorrowerName'
ppp_state_col = 'ProjectState'
warn_company_col = 'employer'
warn_state_col = 'state'

# %%
# TODO implement cacheing
def standardize_company(company_name, cache_dir):
    url = f'https://api.opencorporates.com/v0.4/companies/search?q={company_name}'
    cache_key = company_name
    downloaded_dir = f'{cache_dir}/{cache_key}.json'
    api_json = ""
    try:
        print(f'trying to read company {company_name} from cache...')
        # read from cache
        try:
            api_json = open_json(downloaded_dir)
        except UnicodeDecodeError:
            api_json = open_json(downloaded_dir, encoding="utf-8")

    except (FileNotFoundError, SyntaxError):
        print(f'failed to read from cache. Downloading API data for company {company_name}...')
        # cody's api key
        auth = requests.auth.HTTPBasicAuth('apikey', 'vLHe38cEAyunPAOORaxV')
        file_path = download_file(url, auth=auth, local_path=downloaded_dir)
        try:
            api_json = open_json(file_path)
        except UnicodeDecodeError:
            api_json = open_json(file_path, encoding="utf-8")
#     standardized_company_name = find_canonical(api_json)
    return api_json


def open_json(source_file, encoding=''):
    kwargs = {"newline": "", }
    # work-around for encoding differences between states
    if encoding:
        kwargs["encoding"] = encoding
    output_rows = []
    with open(source_file, **kwargs) as f:
        json_file = json.load(f)
    return json_file


def find_canonical(json):
    json = json['results']
    if json['companies']:
        for company in json['companies']:
            return evaluate_match(company)
    elif json['company']:
        return evaluate_match(company)
    else:
        print('No matching companies found.')
    return None

# %%
# def open_file(source_file, filename, encoding=''):
#     kwargs = {"newline": "", }
#     # work-around for encoding differences
#     if encoding:
#         kwargs["encoding"] = encoding
#     output_rows = []
#     with open(source_file, **kwargs) as f:
#         file = csv.reader(f)
#         for row in file:
#             output_rows.append(row)
#     return output_rows

def process_warn(df):
    df['company_name'] = df[warn_company_col]  # create new col
    df['company_name'] = df['company_name'].str.upper()  # to uppercase
    df['company_name'] = df['company_name'].str.replace(r'[^a-zA-Z ]', r'', regex=True)  # remove non-alphanum chars
    
#     df['canonical_company_name_warn'] = standardize_company(df[warn_company_col], WARN_CACHE_PATH)  # canonicalize
    
    df['company_name'] = df['company_name'].str[:18]  # get first 18 chars
    return df


def process_ppp(df):
    df['company_name'] = df[ppp_company_col]  # create new col
    df['company_name'] = df['company_name'].str.upper()  # to uppercase
    df['company_name'] = df['company_name'].str.replace(r'[^a-zA-Z ]', r'', regex=True)  # remove non-alphanum chars
    
#     df['canonical_company_name_ppp'] = standardize_company(df[ppp_company_col], WARN_CACHE_PATH)  # canonicalize
    
    df['company_name'] = df['company_name'].str[:18]  # get first 18 chars
    return df

def merge(df1, df2):
    # do inner join where company name, state match.
    merged_df = pd.merge(df1, df2, how='inner', left_on=['company_name', warn_state_col], right_on = ['company_name', ppp_state_col])
    return merged_df

# %%
# read in WARN data
try:
    warn_df = pd.read_csv(warn_csv, encoding='ISO-8859-1')
except:
    warn_df = pd.read_csv(warn_csv, encoding='utf-8')
    
# read in PPP data from multiple files
ppp_dfs = []
for file in ppp_csvs:
    try:
        file_df = pd.read_csv(file, encoding='ISO-8859-1')
    except:
        try:
            file_df = pd.read_csv(file, encoding='utf-8')
        except FileNotFoundError:
            print(f"File not found: {file}.")
            # dont try to merge this file
            continue
    ppp_dfs.append(file_df)
    file_df.head()
# Out:
# c:\users\cody-dellxps\.virtualenvs\warn-analysis-pyihy2i0\lib\site-packages\IPython\core\interactiveshell.py:3173: DtypeWarning: Columns (50) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# c:\users\cody-dellxps\.virtualenvs\warn-analysis-pyihy2i0\lib\site-packages\IPython\core\interactiveshell.py:3173: DtypeWarning: Columns (16,50) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
for df in ppp_dfs:
    print(df.head())
# Out:
#    LoanNumber DateApproved  SBAOfficeCode ProcessingMethod  \
# 0  9547507704   05/01/2020            464              PPP
# 1  9777677704   05/01/2020            464              PPP
# 2  5791407702   05/01/2020           1013              PPP
# 3  6223567700   05/01/2020            920              PPP
# 4  9662437702   05/01/2020            101              PPP
#
#                BorrowerName        BorrowerAddress      BorrowerCity  \
# 0     SUMTER COATINGS, INC.  2410 Highway 15 South            Sumter
# 1     PLEASANT PLACES, INC.    7684 Southrail Road  North Charleston
# 2   BOYER CHILDREN'S CLINIC       1850 BOYER AVE E           SEATTLE
# 3  KIRTLEY CONSTRUCTION INC   1661 MARTIN RANCH RD    SAN BERNARDINO
# 4              AERO BOX LLC                    NaN               NaN
#
#   BorrowerState BorrowerZip LoanStatusDate  ...             BusinessType  \
# 0           NaN  29150-9662     12/18/2020  ...              Corporation
# 1           NaN  29420-9000     09/28/2021  ...      Sole Proprietorship
# 2           NaN  98112-2922     03/17/2021  ...  Non-Profit Organization
# 3           NaN  92407-1740     10/16/2021  ...              Corporation
# 4           NaN         NaN     08/17/2021  ...                      NaN
#
#    OriginatingLenderLocationID                      OriginatingLender  \
# 0                        19248                           Synovus Bank
# 1                        19248                           Synovus Bank
# 2                         9551  Bank of America, National Association
# 3                         9551  Bank of America, National Association
# 4                        57328           The Huntington National Bank
#
#    OriginatingLenderCity  OriginatingLenderState      Gender      Veteran  \
# 0               COLUMBUS                      GA  Unanswered   Unanswered
# 1               COLUMBUS                      GA  Male Owned  Non-Veteran
# 2              CHARLOTTE                      NC  Unanswered   Unanswered
# 3              CHARLOTTE                      NC  Unanswered   Unanswered
# 4               COLUMBUS                      OH  Unanswered   Unanswered
#
#    NonProfit ForgivenessAmount ForgivenessDate
# 0        NaN         773553.37      11/20/2020
# 1        NaN         746336.24      08/12/2021
# 2          Y         696677.49      02/10/2021
# 3        NaN         395264.11      09/10/2021
# 4        NaN         370819.35      04/08/2021
#
# [5 rows x 53 columns]
#    LoanNumber DateApproved  SBAOfficeCode ProcessingMethod  \
# 0  3509338307   01/22/2021            NaN              PPS
# 1  5375617707   05/01/2020          101.0              PPP
# 2  9677497701   05/01/2020          464.0              PPP
# 3  9547167709   05/01/2020          464.0              PPP
# 4  8885207205   04/28/2020            NaN              PPP
#
#                              BorrowerName          BorrowerAddress  \
# 0                             Exemption 6                      NaN
# 1                           NOT AVAILABLE                      NaN
# 2  NORTH CHARLESTON HOSPITALITY GROUP LLC      192 College Park Rd
# 3                    Q AND J SERVICES LLC  301 Old Georgetown Road
# 4                             Exemption 6                      NaN
#
#   BorrowerCity BorrowerState BorrowerZip LoanStatusDate  ...  \
# 0          NaN           NaN         NaN            NaN  ...
# 1          NaN           NaN         NaN     07/16/2021  ...
# 2       Ladson           NaN  29456-3517     09/25/2021  ...
# 3      Manning           NaN  29102-2734     04/20/2021  ...
# 4          NaN           NaN         NaN     05/20/2021  ...
#
#                       BusinessType  OriginatingLenderLocationID  \
# 0          Non-Profit Organization                          NaN
# 1                              NaN                       9551.0
# 2  Limited  Liability Company(LLC)                      19248.0
# 3  Limited  Liability Company(LLC)                      19248.0
# 4          Non-Profit Organization                          NaN
#
#                        OriginatingLender  OriginatingLenderCity  \
# 0                                    NaN                    NaN
# 1  Bank of America, National Association              CHARLOTTE
# 2                           Synovus Bank               COLUMBUS
# 3                           Synovus Bank               COLUMBUS
# 4                                    NaN                    NaN
#
#    OriginatingLenderState      Gender     Veteran  NonProfit  \
# 0                     NaN  Unanswered  Unanswered          Y
# 1                      NC  Unanswered  Unanswered        NaN
# 2                      GA  Unanswered  Unanswered        NaN
# 3                      GA  Unanswered  Unanswered        NaN
# 4                     NaN  Unanswered  Unanswered          Y
#
#   ForgivenessAmount ForgivenessDate
# 0               NaN             NaN
# 1         150083.01      06/11/2021
# 2         141920.11      08/25/2021
# 3         137747.78      03/29/2021
# 4         131876.98      04/27/2021
#
# [5 rows x 53 columns]
#    LoanNumber DateApproved  SBAOfficeCode ProcessingMethod  \
# 0  6703358604   03/23/2021            914              PPS
# 1  6703368901   05/02/2021            914              PPP
# 2  6703409003   05/23/2021            912              PPP
# 3  6703497310   04/30/2020            914              PPP
# 4  6703498905   05/02/2021            920              PPP
#
#                        BorrowerName                      BorrowerAddress  \
# 0                      JOEL HOFFMAN               100 Oceangate Ste 1200
# 1                 MIGUEL CASTILLEJO             15616 Vanowen St Apt 108
# 2                    CATANGA WALKER                        5748 Owens Dr
# 3  LAW OFFICE OF CHRISTOPHER RAMSEY  8055 W. Manchester Avenue suite 630
# 4                       NIKKI REESE            13400 Elsworth St Apt 123
#
#     BorrowerCity BorrowerState BorrowerZip LoanStatusDate  ...  \
# 0     Long Beach            CA  90802-4324     09/28/2021  ...
# 1       Van Nuys            CA  91406-5193            NaN  ...
# 2     Pleasanton            CA  94588-4648            NaN  ...
# 3  Playa Del Rey            CA       90293            NaN  ...
# 4  Moreno Valley            CA  92553-8436            NaN  ...
#
#                 BusinessType  OriginatingLenderLocationID  \
# 0  Self-Employed Individuals                       509316
# 1        Sole Proprietorship                       509316
# 2        Sole Proprietorship                       514546
# 3  Self-Employed Individuals                       121536
# 4          Single Member LLC                       509316
#
#                      OriginatingLender  OriginatingLenderCity  \
# 0  Harvest Small Business Finance, LLC           Laguna Hills
# 1  Harvest Small Business Finance, LLC           Laguna Hills
# 2       BSD Capital, LLC dba Lendistry                   Brea
# 3                       Customers Bank           PHOENIXVILLE
# 4  Harvest Small Business Finance, LLC           Laguna Hills
#
#    OriginatingLenderState        Gender      Veteran  NonProfit  \
# 0                      CA    Unanswered   Unanswered        NaN
# 1                      CA    Male Owned  Non-Veteran        NaN
# 2                      CA    Unanswered   Unanswered        NaN
# 3                      PA    Unanswered   Unanswered        NaN
# 4                      CA  Female Owned  Non-Veteran        NaN
#
#   ForgivenessAmount ForgivenessDate
# 0          20907.77      08/18/2021
# 1               NaN             NaN
# 2               NaN             NaN
# 3          20970.55      01/08/2021
# 4               NaN             NaN
#
# [5 rows x 53 columns]
#    LoanNumber DateApproved  SBAOfficeCode ProcessingMethod  \
# 0  9100017910   06/19/2020            156              PPP
# 1  7662528604   03/24/2021            156              PPS
# 2  5769328909   04/30/2021            156              PPP
# 3  4783917403   05/11/2020            156              PPP
# 4  8550827005   04/08/2020            156              PPP
#
#                       BorrowerName                BorrowerAddress  \
# 0         THE KEMPINSKI CLINIC LLC  455 Boston Post Road Suite 7A
# 1         GALLY INVESTMENTS CO LLC                   45 Mather St
# 2                   CRAIG HEUGHINS                 5 Fairview Ave
# 3  LAW OFFICE OF MAYRA M RIOS, LLC                 1200 SUMMER ST
# 4           JOHNSON WINE GROUP LLC                   39 E. Elm ST
#
#    BorrowerCity BorrowerState BorrowerZip LoanStatusDate  ...  \
# 0  Old Saybrook            CT       06413     11/18/2021  ...
# 1    Manchester            CT  06042-2332     10/16/2021  ...
# 2    Deep River            CT  06417-1905     11/11/2021  ...
# 3      STAMFORD            CT       06905     03/10/2021  ...
# 4     GREENWICH            CT  06830-6546     07/08/2021  ...
#
#                       BusinessType  OriginatingLenderLocationID  \
# 0  Limited  Liability Company(LLC)                        16282
# 1                      Corporation                         9551
# 2              Sole Proprietorship                       529192
# 3  Limited  Liability Company(LLC)                        15793
# 4  Limited  Liability Company(LLC)                       123396
#
#                                   OriginatingLender  OriginatingLenderCity  \
# 0                                      Liberty Bank             MIDDLETOWN
# 1             Bank of America, National Association              CHARLOTTE
# 2                                  Benworth Capital                  Miami
# 3        People's United Bank, National Association             BRIDGEPORT
# 4  Connecticut Community Bank, National Association               WESTPORT
#
#    OriginatingLenderState        Gender      Veteran  NonProfit  \
# 0                      CT  Female Owned  Non-Veteran        NaN
# 1                      NC    Male Owned  Non-Veteran        NaN
# 2                      FL    Unanswered   Unanswered        NaN
# 3                      CT    Unanswered   Unanswered        NaN
# 4                      CT    Unanswered   Unanswered        NaN
#
#   ForgivenessAmount ForgivenessDate
# 0          19173.51      10/28/2021
# 1          19007.79      09/22/2021
# 2               NaN             NaN
# 3          19048.85      02/05/2021
# 4          19136.39      06/15/2021
#
# [5 rows x 53 columns]
#    LoanNumber DateApproved  SBAOfficeCode ProcessingMethod  \
# 0  7380298707   04/06/2021            491              PPS
# 1  7409588705   04/06/2021            491              PPP
# 2  7939998609   03/24/2021            491              PPP
# 3  7977198301   01/29/2021            455              PPS
# 4  8055767406   05/18/2020            455              PPP
#
#                              BorrowerName         BorrowerAddress  \
# 0            FIVE FLAGS DANCE ACADEMY LLC    8084 N DAVIS HWY F-1
# 1                            TROY WALDING        8536 Honolulu Dr
# 2                          ANTONIO GALBAN  10407 Falcon Parc Blvd
# 3                   VIP THERAPY OF VB INC            8734 20th St
# 4  HEALTH MANAGEMENT SOLUTIONS ABROAD INC    13458 SW 62 St Q 104
#
#   BorrowerCity BorrowerState BorrowerZip LoanStatusDate  ...  \
# 0    PENSACOLA            FL       32514            NaN  ...
# 1      Orlando            FL  32818-6603            NaN  ...
# 2      Orlando            FL  32832-5505     10/21/2021  ...
# 3   Vero Beach            FL  32966-6956     09/28/2021  ...
# 4        MIAMI            FL  33183-5063     06/18/2021  ...
#
#                       BusinessType  OriginatingLenderLocationID  \
# 0  Limited  Liability Company(LLC)                        39232
# 1        Self-Employed Individuals                       509316
# 2          Independent Contractors                       509316
# 3                      Corporation                         9551
# 4                      Corporation                       225134
#
#                              OriginatingLender  OriginatingLenderCity  \
# 0                         Hancock Whitney Bank               GULFPORT
# 1          Harvest Small Business Finance, LLC           Laguna Hills
# 2          Harvest Small Business Finance, LLC           Laguna Hills
# 3        Bank of America, National Association              CHARLOTTE
# 4  Truist Bank d/b/a Branch Banking & Trust Co              CHARLOTTE
#
#    OriginatingLenderState      Gender     Veteran  NonProfit  \
# 0                      MS  Male Owned     Veteran        NaN
# 1                      CA  Unanswered  Unanswered        NaN
# 2                      CA  Unanswered  Unanswered        NaN
# 3                      NC  Unanswered  Unanswered        NaN
# 4                      NC  Unanswered  Unanswered        NaN
#
#   ForgivenessAmount ForgivenessDate
# 0               NaN             NaN
# 1               NaN             NaN
# 2           3956.42      09/28/2021
# 3           3956.63      08/04/2021
# 4           3976.26      05/27/2021
#
# [5 rows x 53 columns]
#    LoanNumber DateApproved  SBAOfficeCode ProcessingMethod  \
# 0  4442107104   04/13/2020           1087              PPP
# 1  4568927000   04/03/2020           1087              PPP
# 2  4745268001   06/26/2020           1087              PPP
# 3  5049427409   05/11/2020           1087              PPP
# 4  5094637303   04/30/2020           1087              PPP
#
#                        BorrowerName      BorrowerAddress BorrowerCity  \
# 0                     JOSHUA ELISON     763 Frontage Rd.    BLACKFOOT
# 1             DRAGONFLY SALON & SPA  1400 Pomerelle Ave.       BURLEY
# 2                      LEENA WEAVER      4904 E LEWIS LN        NAMPA
# 3  MAXFIELD HEALTHCARE SOLUTIONS PC         143 N 3762 E        Rigby
# 4                  KELCEY SCHROEDER   3850 E Michelle St  Idaho Falls
#
#   BorrowerState BorrowerZip LoanStatusDate  ...               BusinessType  \
# 0            ID       83221     06/22/2021  ...  Self-Employed Individuals
# 1            ID  83318-2064     04/22/2021  ...                Partnership
# 2            ID  83686-9008     02/03/2021  ...        Sole Proprietorship
# 3            ID       83442     04/21/2021  ...   Subchapter S Corporation
# 4            ID       83401     05/25/2021  ...        Sole Proprietorship
#
#    OriginatingLenderLocationID          OriginatingLender  \
# 0                       106925       Mountain America FCU
# 1                        20132           D. L. Evans Bank
# 2                        96211           Idaho Central CU
# 3                        72601  Zions Bank, A Division of
# 4                        20132           D. L. Evans Bank
#
#    OriginatingLenderCity  OriginatingLenderState        Gender      Veteran  \
# 0                  SANDY                      UT    Unanswered   Unanswered
# 1                 BURLEY                      ID    Unanswered   Unanswered
# 2               CHUBBUCK                      ID  Female Owned  Non-Veteran
# 3         SALT LAKE CITY                      UT    Male Owned  Non-Veteran
# 4                 BURLEY                      ID  Female Owned  Non-Veteran
#
#    NonProfit ForgivenessAmount ForgivenessDate
# 0        NaN           3336.62      06/02/2021
# 1        NaN           3331.46      03/25/2021
# 2        NaN           3317.27      01/07/2021
# 3        NaN           3330.29      04/13/2021
# 4        NaN           3330.47      04/08/2021
#
# [5 rows x 53 columns]
#    LoanNumber DateApproved  SBAOfficeCode ProcessingMethod  \
# 0  3459648405   02/05/2021            457              PPS
# 1  1552118503   02/19/2021            457              PPS
# 2  6958117205   04/28/2020            457              PPP
# 3  4784968503   02/26/2021            457              PPP
# 4  6822158900   05/03/2021            457              PPS
#
#                        BorrowerName               BorrowerAddress  \
# 0        UNLIMITED RESTORATIONS INC             8407 Winnipeg Way
# 1                     KERRY CUNDIFF  323 S Wallace Wilkinson Blvd
# 2  CUNDIFF FAMILY CHIROPRACTIC, PSC    256 Wallace Wilkinson Blvd
# 3     D&M MECHANICAL INSULATION LLC             238 Derby Ave N/A
# 4     D&M MECHANICAL INSULATION LLC             238 Derby Ave N/A
#
#   BorrowerCity BorrowerState BorrowerZip LoanStatusDate  ...  \
# 0   Louisville            KY  40228-7809     11/18/2021  ...
# 1      Liberty            KY  42539-3339            NaN  ...
# 2      LIBERTY            KY  42539-3013            NaN  ...
# 3   Louisville            KY  40218-3216            NaN  ...
# 4   Louisville            KY  40218-3216            NaN  ...
#
#                       BusinessType  OriginatingLenderLocationID  \
# 0         Subchapter S Corporation                        48270
# 1              Sole Proprietorship                        27035
# 2              Sole Proprietorship                        27035
# 3  Limited  Liability Company(LLC)                       121536
# 4  Limited  Liability Company(LLC)                       121536
#
#                            OriginatingLender  OriginatingLenderCity  \
# 0  JPMorgan Chase Bank, National Association               COLUMBUS
# 1                               Peoples Bank                LEBANON
# 2                               Peoples Bank                LEBANON
# 3                             Customers Bank           PHOENIXVILLE
# 4                             Customers Bank           PHOENIXVILLE
#
#    OriginatingLenderState      Gender     Veteran  NonProfit  \
# 0                      OH  Unanswered  Unanswered        NaN
# 1                      KY  Male Owned  Unanswered        NaN
# 2                      KY  Male Owned  Unanswered        NaN
# 3                      PA  Unanswered  Unanswered        NaN
# 4                      PA  Unanswered  Unanswered        NaN
#
#   ForgivenessAmount ForgivenessDate
# 0          27152.52      10/06/2021
# 1          27072.59      08/16/2021
# 2          19080.51      11/23/2020
# 3          27131.14      10/06/2021
# 4               NaN             NaN
#
# [5 rows x 53 columns]
#    LoanNumber DateApproved  SBAOfficeCode ProcessingMethod  \
# 0  8011508610   03/24/2021            515              PPP
# 1  2063658505   02/19/2021            515              PPP
# 2  2483998607   03/15/2021            515              PPS
# 3  5660457706   05/01/2020            515              PPP
# 4  6439327207   04/28/2020            515              PPP
#
#                     BorrowerName         BorrowerAddress    BorrowerCity  \
# 0                  LORRAINE RACE      1363 Sierra Ave NW          Walker
# 1                  DENNIS BURLEW       3300 Duck Lake Rd           Allen
# 2           BRIDGETTE MARIE FRYE           301 W Lake St  Harbor Springs
# 3      L AND R MANUFACTURING LLC   4696 W GRAND RIVER RD     WEBBERVILLE
# 4  S. NORDSTROM TAX SERVICE, LLC  3105 CABARET TRL STE A         SAGINAW
#
#   BorrowerState BorrowerZip LoanStatusDate  ...  \
# 0            MI  49534-2255            NaN  ...
# 1            MI  49227-9559            NaN  ...
# 2            MI  49740-1153            NaN  ...
# 3            MI  48892-9273     07/22/2021  ...
# 4            MI  48603-2269     03/09/2021  ...
#
#                       BusinessType  OriginatingLenderLocationID  \
# 0              Sole Proprietorship                        29599
# 1        Self-Employed Individuals                        35318
# 2              Sole Proprietorship                       529050
# 3  Limited  Liability Company(LLC)                         9551
# 4  Limited  Liability Company(LLC)                        77961
#
#                        OriginatingLender  OriginatingLenderCity  \
# 0                         Northeast Bank               LEWISTON
# 1                   County National Bank              HILLSDALE
# 2                    Square Capital, LLC          San Francisco
# 3  Bank of America, National Association              CHARLOTTE
# 4                       Independent Bank           GRAND RAPIDS
#
#    OriginatingLenderState        Gender      Veteran  NonProfit  \
# 0                      ME  Female Owned  Non-Veteran        NaN
# 1                      MI    Unanswered   Unanswered        NaN
# 2                      CA    Unanswered   Unanswered        NaN
# 3                      NC    Male Owned  Non-Veteran        NaN
# 4                      MI    Unanswered   Unanswered        NaN
#
#   ForgivenessAmount ForgivenessDate
# 0          10314.56      11/01/2021
# 1          10308.21      09/09/2021
# 2               NaN             NaN
# 3          10350.75      04/15/2021
# 4          10331.09      02/04/2021
#
# [5 rows x 53 columns]
#    LoanNumber DateApproved  SBAOfficeCode ProcessingMethod  \
# 0  2929617107   04/11/2020            875              PPP
# 1  4025567210   04/27/2020            875              PPP
# 2  4492797001   04/03/2020            875              PPP
# 3  5006357205   04/27/2020            875              PPP
# 4  9045737104   04/15/2020            875              PPP
#
#                      BorrowerName             BorrowerAddress BorrowerCity  \
# 0                JOE BLACK'S, INC                118 N 3rd St  GRAND FORKS
# 1         ON POINT EXCAVATING LLC             500 111th St SE       SURREY
# 2      GRAFSTROM CONSTRUCTION LLC           1349 4th Street N        FARGO
# 3  THE FARGO BREWING COMPANY, LLC  610 University Drive North        FARGO
# 4                2 VETS MOVING CO            811 S 18TH ST #C     BISMARCK
#
#   BorrowerState BorrowerZip LoanStatusDate  ...  \
# 0            ND  58203-3716     01/22/2021  ...
# 1            ND  58785-9000     03/10/2021  ...
# 2            ND  58102-2712     02/18/2021  ...
# 3            ND  58102-4342     03/10/2021  ...
# 4            ND  58504-6116     12/16/2020  ...
#
#                       BusinessType  OriginatingLenderLocationID  \
# 0         Subchapter S Corporation                        52701
# 1  Limited  Liability Company(LLC)                        52905
# 2  Limited  Liability Company(LLC)                        52722
# 3  Limited  Liability Company(LLC)                        52905
# 4         Subchapter S Corporation                       118060
#
#             OriginatingLender  OriginatingLenderCity  OriginatingLenderState  \
# 0          United Valley Bank               CAVALIER                      ND
# 1  First Western Bank & Trust                  MINOT                      ND
# 2            Cornerstone Bank                  FARGO                      ND
# 3  First Western Bank & Trust                  MINOT                      ND
# 4                Starion Bank               BISMARCK                      ND
#
#        Gender      Veteran  NonProfit ForgivenessAmount ForgivenessDate
# 0  Unanswered   Unanswered        NaN         107815.52      11/23/2020
# 1  Unanswered   Unanswered        NaN         107695.00      11/23/2020
# 2  Male Owned  Non-Veteran        NaN         117871.00      01/07/2021
# 3  Male Owned  Non-Veteran        NaN         107683.61      12/17/2020
# 4  Unanswered   Unanswered        NaN         117669.95      11/20/2020
#
# [5 rows x 53 columns]
#    LoanNumber DateApproved  SBAOfficeCode ProcessingMethod  \
# 0  9550948900   05/12/2021            202              PPP
# 1  9551008902   05/12/2021            202              PPP
# 2  9551428409   02/17/2021            202              PPS
# 3  9551628900   05/12/2021            202              PPP
# 4  9551748302   01/31/2021            202              PPS
#
#                 BorrowerName       BorrowerAddress         BorrowerCity  \
# 0               IRVIN POWELL        18411 144th Rd  Springfield Gardens
# 1              ASHELYN ARIAS    468 New Jersey Ave             Brooklyn
# 2      CYCLE INTERACTIVE LLC  504 Grand St Apt B61             New York
# 3             ELIZABETH CALO     1998 Bathgate Ave                Bronx
# 4  RICHARD LONINGER DPM P.C.         121 E 60th St             New York
#
#   BorrowerState BorrowerZip LoanStatusDate  ...  \
# 0            NY  11413-3326            NaN  ...
# 1            NY  11207-4715            NaN  ...
# 2            NY  10002-4147     11/19/2021  ...
# 3            NY  10457-4407            NaN  ...
# 4            NY  10022-1117            NaN  ...
#
#                       BusinessType  OriginatingLenderLocationID  \
# 0          Independent Contractors                       188361
# 1              Sole Proprietorship                       188361
# 2  Limited  Liability Company(LLC)                        48270
# 3              Sole Proprietorship                       188361
# 4              Sole Proprietorship                        48270
#
#                            OriginatingLender  OriginatingLenderCity  \
# 0                        Prestamos CDFI, LLC                Phoenix
# 1                        Prestamos CDFI, LLC                Phoenix
# 2  JPMorgan Chase Bank, National Association               COLUMBUS
# 3                        Prestamos CDFI, LLC                Phoenix
# 4  JPMorgan Chase Bank, National Association               COLUMBUS
#
#    OriginatingLenderState        Gender      Veteran  NonProfit  \
# 0                      AZ    Male Owned   Unanswered        NaN
# 1                      AZ  Female Owned  Non-Veteran        NaN
# 2                      OH    Unanswered   Unanswered        NaN
# 3                      AZ  Female Owned  Non-Veteran        NaN
# 4                      OH    Unanswered   Unanswered        NaN
#
#   ForgivenessAmount ForgivenessDate
# 0               NaN             NaN
# 1          20910.70      10/14/2021
# 2          20973.21      10/26/2021
# 3               NaN             NaN
# 4               NaN             NaN
#
# [5 rows x 53 columns]
#    LoanNumber DateApproved  SBAOfficeCode ProcessingMethod  \
# 0  9375668705   04/08/2021           1086              PPP
# 1  2832257404   05/06/2020           1086              PPP
# 2  3480028706   03/31/2021           1086              PPP
# 3  6025078004   06/29/2020           1086              PPP
# 4  6834967407   05/15/2020           1086              PPP
#
#                           BorrowerName            BorrowerAddress  \
# 0                      LORI WEATHERWAX   2020 SE 7th Ave Unit 100
# 1  JENNIFER BAINES INTERIOR DESIGN LLC      2209 NE KLICKITAT ST.
# 2                        KIMBER WATSON           80718 Forcade Ln
# 3                  ELEGANT NAILS 2 LLC  4130 SW 117TH AVE Suite B
# 4                   TIMELESS NAILS,LLC         4173 COWBOY AVE SE
#
#   BorrowerCity BorrowerState BorrowerZip LoanStatusDate  ...  \
# 0     Portland            OR  97214-4603            NaN  ...
# 1     PORTLAND            OR       97212     10/21/2021  ...
# 2    Hermiston            OR  97838-7352            NaN  ...
# 3    BEAVERTON            OR  97005-2209     05/21/2021  ...
# 4       ALBANY            OR       97322     03/23/2021  ...
#
#                       BusinessType  OriginatingLenderLocationID  \
# 0              Sole Proprietorship                       530223
# 1         Subchapter S Corporation                        12096
# 2              Sole Proprietorship                       103692
# 3  Limited  Liability Company(LLC)                        48270
# 4  Limited  Liability Company(LLC)                        53803
#
#                            OriginatingLender  OriginatingLenderCity  \
# 0                    American Lending Center             Long Beach
# 1     Wells Fargo Bank, National Association            SIOUX FALLS
# 2                               Old West FCU               JOHN DAY
# 3  JPMorgan Chase Bank, National Association               COLUMBUS
# 4            U.S. Bank, National Association             CINCINNATI
#
#    OriginatingLenderState      Gender     Veteran  NonProfit  \
# 0                      CA  Unanswered  Unanswered        NaN
# 1                      SD  Unanswered  Unanswered        NaN
# 2                      OR  Unanswered  Unanswered        NaN
# 3                      OH  Unanswered  Unanswered        NaN
# 4                      OH  Unanswered  Unanswered        NaN
#
#   ForgivenessAmount ForgivenessDate
# 0          12962.37      10/22/2021
# 1          13073.01      09/21/2021
# 2          12961.90      10/06/2021
# 3          12992.24      04/05/2021
# 4           9951.62      12/14/2020
#
# [5 rows x 53 columns]
#    LoanNumber DateApproved  SBAOfficeCode ProcessingMethod  \
# 0  2378048406   02/03/2021            681              PPS
# 1  6116548902   05/01/2021            610              PPP
# 2  4404827205   04/27/2020            671              PPP
# 3  3071237702   05/01/2020            610              PPP
# 4  1643288405   02/02/2021            610              PPS
#
#                                    BorrowerName               BorrowerAddress  \
# 0                                 H.I.S. CENTRE              1781 E Ammann Rd
# 1  RELIABLE WRECKER & ROADSIDE ASSISTANCE CORP.              3809 Dividend Dr
# 2                      KINGS CROSS VENTURES LLC                400 W PARKWOOD
# 3                TAMMY R. WEYANDT, D.D.S., P.A.              698 S WATTERS RD
# 4                GOODRICH REALTY CONSULTING LLC  7200 W University Dr Ste 324
#
#   BorrowerCity BorrowerState BorrowerZip LoanStatusDate  ...  \
# 0     Bulverde            TX  78163-2034     08/06/2021  ...
# 1      Garland            TX  75042-7613     11/18/2021  ...
# 2  FRIENDSWOOD            TX  77546-5425     04/15/2021  ...
# 3        ALLEN            TX       75013     04/22/2021  ...
# 4     McKinney            TX  75071-7206     10/07/2021  ...
#
#                       BusinessType  OriginatingLenderLocationID  \
# 0          Non-Profit Organization                        71727
# 1                      Corporation                        48270
# 2  Limited  Liability Company(LLC)                        69994
# 3                      Corporation                        48270
# 4  Limited  Liability Company(LLC)                        68987
#
#                            OriginatingLender  OriginatingLenderCity  \
# 0                     Broadway National Bank            SAN ANTONIO
# 1  JPMorgan Chase Bank, National Association               COLUMBUS
# 2                        Moody National Bank              GALVESTON
# 3  JPMorgan Chase Bank, National Association               COLUMBUS
# 4                           Independent Bank               MCKINNEY
#
#    OriginatingLenderState        Gender      Veteran  NonProfit  \
# 0                      TX    Unanswered   Unanswered          Y
# 1                      OH    Unanswered   Unanswered        NaN
# 2                      TX    Male Owned  Non-Veteran        NaN
# 3                      OH  Female Owned  Non-Veteran        NaN
# 4                      TX    Unanswered   Unanswered        NaN
#
#   ForgivenessAmount ForgivenessDate
# 0          90813.75      07/02/2021
# 1          90903.39      10/19/2021
# 2          91290.77      03/29/2021
# 3          91272.78      03/17/2021
# 4          91060.59      09/22/2021
#
# [5 rows x 53 columns]
#    LoanNumber DateApproved  SBAOfficeCode ProcessingMethod  \
# 0  1436678303   01/17/2021            353              PPS
# 1  4975507207   04/27/2020            304              PPP
# 2  9869848406   02/18/2021            304              PPS
# 3  1410308408   02/01/2021            304              PPS
# 4  5723157403   05/13/2020            304              PPP
#
#                       BorrowerName        BorrowerAddress     BorrowerCity  \
# 0  RC CONSTRUCTION ENTERPRISES INC   3150 Spring St Ste F          Fairfax
# 1              LOUIE WHOLESALE LLC  2836 East Parham Road         Richmond
# 2            SLICK ROCK LUMBER LLC     3074 Slick Rock Rd         Nathalie
# 3                   SAIKISHAN INC.      200 Lilly Bell Dr        Lexington
# 4            VIBETHINK CORPORATION  258 Blue Springs Lane  Charlottesville
#
#   BorrowerState BorrowerZip LoanStatusDate  ...  \
# 0            VA  22031-2324     11/20/2021  ...
# 1            VA  23228-2918     04/17/2021  ...
# 2            VA  24577-2510     08/17/2021  ...
# 3            VA  24450-3797     10/20/2021  ...
# 4            VA       22903     05/19/2021  ...
#
#                       BusinessType  OriginatingLenderLocationID  \
# 0                      Corporation                       499141
# 1  Limited  Liability Company(LLC)                        61021
# 2  Limited  Liability Company(LLC)                        73215
# 3                      Corporation                        73903
# 4                      Corporation                       225134
#
#                              OriginatingLender  OriginatingLenderCity  \
# 0                        Readycap Lending, LLC       BERKELEY HEIGHTS
# 1                                    Mars Bank                   MARS
# 2     American National Bank and Trust Company               DANVILLE
# 3                                   First Bank              STRASBURG
# 4  Truist Bank d/b/a Branch Banking & Trust Co              CHARLOTTE
#
#    OriginatingLenderState        Gender      Veteran  NonProfit  \
# 0                      NJ    Male Owned  Non-Veteran        NaN
# 1                      PA  Female Owned   Unanswered        NaN
# 2                      VA    Male Owned  Non-Veteran        NaN
# 3                      VA    Unanswered   Unanswered        NaN
# 4                      NC    Unanswered   Unanswered        NaN
#
#   ForgivenessAmount ForgivenessDate
# 0         104812.65      10/14/2021
# 1         104963.74      03/17/2021
# 2         104474.00      07/14/2021
# 3         104723.15      10/08/2021
# 4         104993.42      04/26/2021
#
# [5 rows x 53 columns]

# %%
# merge each ppp file into one complete ppp dataframe
# check to see that ppp_df is non-empty before trying to merge
ppp_df = pd.concat(ppp_dfs)
ppp_df.head()
# Out:
#    LoanNumber DateApproved  SBAOfficeCode ProcessingMethod  \
# 0  9547507704   05/01/2020          464.0              PPP
# 1  9777677704   05/01/2020          464.0              PPP
# 2  5791407702   05/01/2020         1013.0              PPP
# 3  6223567700   05/01/2020          920.0              PPP
# 4  9662437702   05/01/2020          101.0              PPP
#
#                BorrowerName        BorrowerAddress      BorrowerCity  \
# 0     SUMTER COATINGS, INC.  2410 Highway 15 South            Sumter
# 1     PLEASANT PLACES, INC.    7684 Southrail Road  North Charleston
# 2   BOYER CHILDREN'S CLINIC       1850 BOYER AVE E           SEATTLE
# 3  KIRTLEY CONSTRUCTION INC   1661 MARTIN RANCH RD    SAN BERNARDINO
# 4              AERO BOX LLC                    NaN               NaN
#
#   BorrowerState BorrowerZip LoanStatusDate  ...             BusinessType  \
# 0           NaN  29150-9662     12/18/2020  ...              Corporation
# 1           NaN  29420-9000     09/28/2021  ...      Sole Proprietorship
# 2           NaN  98112-2922     03/17/2021  ...  Non-Profit Organization
# 3           NaN  92407-1740     10/16/2021  ...              Corporation
# 4           NaN         NaN     08/17/2021  ...                      NaN
#
#    OriginatingLenderLocationID                      OriginatingLender  \
# 0                      19248.0                           Synovus Bank
# 1                      19248.0                           Synovus Bank
# 2                       9551.0  Bank of America, National Association
# 3                       9551.0  Bank of America, National Association
# 4                      57328.0           The Huntington National Bank
#
#    OriginatingLenderCity  OriginatingLenderState      Gender      Veteran  \
# 0               COLUMBUS                      GA  Unanswered   Unanswered
# 1               COLUMBUS                      GA  Male Owned  Non-Veteran
# 2              CHARLOTTE                      NC  Unanswered   Unanswered
# 3              CHARLOTTE                      NC  Unanswered   Unanswered
# 4               COLUMBUS                      OH  Unanswered   Unanswered
#
#    NonProfit ForgivenessAmount ForgivenessDate
# 0        NaN         773553.37      11/20/2020
# 1        NaN         746336.24      08/12/2021
# 2          Y         696677.49      02/10/2021
# 3        NaN         395264.11      09/10/2021
# 4        NaN         370819.35      04/08/2021
#
# [5 rows x 53 columns]

# %%
# pre-process WARN, PPP data for merge
warn_df = process_warn(warn_df)
ppp_df = process_ppp(ppp_df)

# merge warn, ppp data
merged_df = merge(warn_df, ppp_df)
merged_df.head()
# Out:
#   state                        employer number_affected date_received_raw  \
# 0    AK             Doyon Drilling Inc.             304            5/1/20
# 1    AK  South Restaurant & Coffeehouse              82            4/2/20
# 2    AK  South Restaurant & Coffeehouse              82            4/2/20
# 3    AL    National Packaging Co.  Inc.              62        06/30/2021
# 4    AL              Standard Furniture              87        10/26/2020
#
#      date_layoff_raw date_closure_raw     location parent_location industry  \
# 0  4/7/20 to 5/31/20              NaN  North Slope             NaN      NaN
# 1            4/17/20              NaN    Anchorage             NaN      NaN
# 2            4/17/20              NaN    Anchorage             NaN      NaN
# 3         08/07/2021              NaN      Decatur             NaN      NaN
# 4         12/23/2020              NaN  Bay Minette             NaN      NaN
#
#                  notes  ...                     BusinessType  \
# 0  COVID-19; permanent  ...                      Corporation
# 1             COVID-19  ...  Limited  Liability Company(LLC)
# 2             COVID-19  ...  Limited  Liability Company(LLC)
# 3                  NaN  ...         Subchapter S Corporation
# 4                  NaN  ...                      Corporation
#
#   OriginatingLenderLocationID             OriginatingLender  \
# 0                     56102.0  KeyBank National Association
# 1                    116975.0                 Northrim Bank
# 2                      3386.0    First National Bank Alaska
# 3                    453618.0       Progress Bank and Trust
# 4                    434138.0              ServisFirst Bank
#
#    OriginatingLenderCity OriginatingLenderState        Gender      Veteran  \
# 0              CLEVELAND                     OH    Unanswered   Unanswered
# 1              ANCHORAGE                     AK  Female Owned  Non-Veteran
# 2              ANCHORAGE                     AK  Female Owned  Non-Veteran
# 3             HUNTSVILLE                     AL  Female Owned   Unanswered
# 4             BIRMINGHAM                     AL    Unanswered   Unanswered
#
#    NonProfit ForgivenessAmount  ForgivenessDate
# 0        NaN         963802.85       01/20/2021
# 1        NaN               NaN              NaN
# 2        NaN         696703.89       01/25/2021
# 3        NaN        1313738.65       11/05/2020
# 4        NaN         612227.23       02/25/2021
#
# [5 rows x 70 columns]

# %%
merged_df.to_csv(output_csv)
